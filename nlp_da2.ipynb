# %%
from nltk.corpus import PlaintextCorpusReader

# %%
corpus_root = '/content/text files'

# %%
wordlists = PlaintextCorpusReader(corpus_root, '.*')

# %%
wordlists.fileids()
# Out:
# ['char.txt', 'do.txt', 'ek.txt', 'panch.txt', 'thin.txt']

# %%
wordlists.words('ek.txt')
# Out:
# ['If', 'you', 'were', 'a', 'member', 'of', 'the', ...]

# %%
#

# %%
#1d stop words removal
import io 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize  
stop_words = set(stopwords.words('english')) 
file1 = open("/content/text files/ek.txt") 
line = file1.read()
words = line.split() 
for r in words: 
    if not r in stop_words: 
        appendFile = open('filteredtext.txt','a') 
        appendFile.write(" "+r) 
        appendFile.close()

# %%
wordlists.words('/content/filteredtext.txt')
# Out:
# ['If', 'member', 'Bloods', 'became', 'paralyzed', ...]

# %%
#

# %%
#1e stemming
aq=wordlists.raw('/content/text files/thin.txt')
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
stopword = stopwords.words('english')
snowball_stemmer = SnowballStemmer('english')
text = aq
word_tokens = nltk.word_tokenize(text)
stemmed_word = [snowball_stemmer.stem(word) for word in word_tokens]
print (stemmed_word)
# Out:
# ['a', 'taglin', 'for', 'a', 'car', 'compani', 'that', 'pride', 'itself', 'on', 'it', 'moral', 'and', 'ethic', ':', 'take', 'the', 'high', 'road', '.', 'thank', 'you', 'for', 'use', 'my', 'word', 'in', 'your', 'work', '.', 'if', 'you', 'were', 'a', 'member', 'of', 'the', 'blood', 'and', 'becam', 'paralyz', 'do', 'you', 'then', 'becom', 'a', 'member', 'of', 'the', 'crip', '?', '.', 'if', 'you', 'work', 'for', 'an', 'ad', 'agenc', 'and', 'get', 'paid', 'for', 'it', 'are', "n't", 'you', 'the', 'one', 'who', 'is', 'be', 'influenc', 'by', 'advertis', '?', '.', 'logan', 'broger', 'is', '``', 'amaz', "''", 'and', 'a', '``', 'wonder', 'boy', "''", 'accord', 'to', 'logan', "'s", 'mom', '.', 'felinamiss', '.', 'if', 'a', 'dog', 'and', 'cat', 'had', 'a', 'babi', 'togeth', 'that', 'grew', 'up', 'and', 'work', 'a', 'desk', 'job', 'he', "'d", 'be', 'a', 'cog', 'in', 'the', 'machin', '.', 'rumour', 'has', 'it', 'target', 'onlin', 'advertis', 'was', 'develop', 'becaus', 'the', 'internet', 'was', 'ups
# ...

# %%
aq=wordlists.sents('/content/text files/thin.txt')
aq
# Out:
# [['A', 'tagline', 'for', 'a', 'car', 'company', 'that', 'prides', 'itself', 'on', 'its', 'morals', 'and', 'ethics', ':', 'Take', 'the', 'High', 'Road', '.'], ['Thank', 'you', 'for', 'using', 'my', 'words', 'in', 'your', 'work', '.'], ...]

# %%
#

# %%
#1f lemmatization
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

stopword = stopwords.words('english')
wordnet_lemmatizer = WordNetLemmatizer()
aqq= wordlists.raw()
word_tokens = nltk.word_tokenize(aqq)
lemmatized_word = [wordnet_lemmatizer.lemmatize(word) for word in word_tokens]
print (lemmatized_word)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# ...

# %%
aqq
# Out:
# 'A tagline for a car company that prides itself on its morals and ethics: Take the High Road. I\'m in a band that does Metallica covers with our private parts - it\'s called Myphallica. Petrovache. If you wake up with a giant zit, you are really facing your fears when you look in the mirror. If the word kerning is kerned poorly, it kind of looks like learning - which is appropriate because both are important. Thank you for using my words in your work.\r\n\r\nYou know the Grammys are a joke when Future doesn\'t win Best Everything. This is a true fact: I never had a fear of heights until I fell off a roof. I bet most serial killers play the drums. I\'m in a band that does Metallica covers with our private parts - it\'s called Myphallica. Petrovache. If Fantasy Hockey actually lived up to its name, every team would have Henrik Lundqvist and Joffrey Lupul on it.\r\n\r\nNorth America should be called Russia since people are always moving so fast. Gralitica. North America should be called
# ...

# %%
#

# %%
#1g parts of speech tagger
import nltk
nltk.download('averaged_perceptron_tagger')
aqqq= wordlists.raw()
word = nltk.word_tokenize(aqqq)
pos_tag = nltk.pos_tag(word)
print (pos_tag)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# ...

# %%
#

# %%
#1c lowercase
aqqqq= wordlists.raw()
lower_text = aqqqq.lower()
print (lower_text)
# Out:
# a tagline for a car company that prides itself on its morals and ethics: take the high road. i'm in a band that does metallica covers with our private parts - it's called myphallica. petrovache. if you wake up with a giant zit, you are really facing your fears when you look in the mirror. if the word kerning is kerned poorly, it kind of looks like learning - which is appropriate because both are important. thank you for using my words in your work.
#
# you know the grammys are a joke when future doesn't win best everything. this is a true fact: i never had a fear of heights until i fell off a roof. i bet most serial killers play the drums. i'm in a band that does metallica covers with our private parts - it's called myphallica. petrovache. if fantasy hockey actually lived up to its name, every team would have henrik lundqvist and joffrey lupul on it.
#
# ...

# %%
#1a word tokenization
aqqqqq= wordlists.raw()
word_tokens = nltk.word_tokenize(aqqqqq)
print (word_tokens)
# Out:
# ['A', 'tagline', 'for', 'a', 'car', 'company', 'that', 'prides', 'itself', 'on', 'its', 'morals', 'and', 'ethics', ':', 'Take', 'the', 'High', 'Road', '.', 'I', "'m", 'in', 'a', 'band', 'that', 'does', 'Metallica', 'covers', 'with', 'our', 'private', 'parts', '-', 'it', "'s", 'called', 'Myphallica', '.', 'Petrovache', '.', 'If', 'you', 'wake', 'up', 'with', 'a', 'giant', 'zit', ',', 'you', 'are', 'really', 'facing', 'your', 'fears', 'when', 'you', 'look', 'in', 'the', 'mirror', '.', 'If', 'the', 'word', 'kerning', 'is', 'kerned', 'poorly', ',', 'it', 'kind', 'of', 'looks', 'like', 'learning', '-', 'which', 'is', 'appropriate', 'because', 'both', 'are', 'important', '.', 'Thank', 'you', 'for', 'using', 'my', 'words', 'in', 'your', 'work', '.', 'You', 'know', 'the', 'Grammys', 'are', 'a', 'joke', 'when', 'Future', 'does', "n't", 'win', 'Best', 'Everything', '.', 'This', 'is', 'a', 'true', 'fact', ':', 'I', 'never', 'had', 'a', 'fear', 'of', 'heights', 'until', 'I', 'fell', 'off', 'a', 
# ...

# %%
#1b sentence tokenization
tranack= wordlists.raw()
sent_token = nltk.sent_tokenize(tranack)
print (sent_token)
# Out:
# ['A tagline for a car company that prides itself on its morals and ethics: Take the High Road.', "I'm in a band that does Metallica covers with our private parts - it's called Myphallica.", 'Petrovache.', 'If you wake up with a giant zit, you are really facing your fears when you look in the mirror.', 'If the word kerning is kerned poorly, it kind of looks like learning - which is appropriate because both are important.', 'Thank you for using my words in your work.', "You know the Grammys are a joke when Future doesn't win Best Everything.", 'This is a true fact: I never had a fear of heights until I fell off a roof.', 'I bet most serial killers play the drums.', "I'm in a band that does Metallica covers with our private parts - it's called Myphallica.", 'Petrovache.', 'If Fantasy Hockey actually lived up to its name, every team would have Henrik Lundqvist and Joffrey Lupul on it.', 'North America should be called Russia since people are always moving so fast.', 'Gralitica.', 'North 
# ...
